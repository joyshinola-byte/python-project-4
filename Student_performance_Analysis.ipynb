# %% [markdown]
# **Install Faker**

# %%
pip install faker
# Out:
# Requirement already satisfied: faker in /usr/local/lib/python3.12/dist-packages (40.11.1)

# %%
from faker import Faker

# %%
fake = Faker()

# %% [markdown]
# **Data** **set**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
names = [fake.name() for _ in range(250)]
data={
"student id":np.random.randint(18,65,250),
"Name":np.random.choice(names,250),
"Gender":np.random.choice(["Male","Female"],250),
"Department":np.random.choice(["IT","HR","Finance","Marketing","Sales"],250),
"Year":np.random.randint(2025,2028,250),
"Maths":np.random.randint(0,100,250),
"science":np.random.randint(0,100,250),
"English":np.random.randint(0,100,250),
"Attendence":np.random.randint(50,100,250),
"Internal mark":np.random.randint(0,25,250)
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      student id              Name  Gender Department  Year  Maths  science  \
# 0            64      Miguel Clark  Female  Marketing  2025     36       25
# 1            31       Jose Clarke  Female    Finance  2026     36       82
# 2            21     Peter Simpson    Male         IT  2025     90       45
# 3            30   Robert Robinson    Male         HR  2027     80       34
# 4            46  Tasha Valenzuela  Female    Finance  2027     93       21
# ..          ...               ...     ...        ...   ...    ...      ...
# 245          43   Alexis Gallegos  Female         IT  2026     22       74
# 246          18      Joanna Arias  Female      Sales  2026     93        6
# 247          32      Thomas Davis  Female  Marketing  2026     65       80
# 248          26    Shelley Monroe    Male    Finance  2026     87       25
# 249          49     Steven Carson    Male    Finance  2025     22       51
#
#      English  Attendence  Internal mark
# 0         69          55             23
# 1         19          74             23
# 2         11          54              7
# 3         19          85              8
# 4         53          88             12
# ..       ...         ...            ...
# 245       78          59             13
# 246       18          61              6
# 247       34          56              0
# 248       30          88              5
# 249       77          93             15
#
# [250 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# student id       0
# Name             0
# Gender           0
# Department       0
# Year             0
# Maths            0
# science          0
# English          0
# Attendence       0
# Internal mark    0
# dtype: int64

# %%
df["Total"] = df["Maths"] + df["science"] + df["English"]
df["Average"] = df["Total"] / 3

# %%
df["Grade"] = df["Average"].apply(lambda x: "A" if x>=85 else "B" if x>=70 else "C" if x>=50 else "Fail")

# %%
print("\nTop Students:\n", df.nlargest(5, "Average")[["Name","Average","Grade"]])
# Out:
# Top Students:
#                           Name    Average Grade
# 102            Charles Hinton  89.000000     A
# 15                Kyle Carter  84.666667     B
# 242             Vincent Hayes  84.666667     B
# 180  Mrs. Jessica Goodman DDS  82.000000     B
# 87             David Wood DDS  81.666667     B

# %% [markdown]
# **Bar Chart**

# %%
plt.scatter(df["Attendence"], df["Average"])
plt.xlabel("Attendance")
plt.ylabel("Average Marks")
plt.title("Attendance vs Performance")
plt.show()

# %% [markdown]
# **Pie chart**

# %%
plt.figure()
df["Gender"].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# **Histogram**

# %%
plt.figure()
plt.hist(df["Average"], bins=10)
plt.title("Distribution of Average Marks")
plt.xlabel("Average Marks")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Scatter plot**

# %%
plt.figure()
plt.scatter(df["Attendence"], df["Average"])
plt.title("Attendance vs Average Marks")
plt.xlabel("Attendance")
plt.ylabel("Average Marks")
plt.show()
