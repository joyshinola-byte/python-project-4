# %% [markdown]
# **Install Faker**

# %%
pip install faker
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 74.7 MB/s eta 0:00:00
# ...

# %%
from faker import Faker

# %%
fake = Faker()

# %% [markdown]
# **Data** **set**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
names = [fake.name() for _ in range(250)]
data={
"student id":np.random.randint(18,65,250),
"Name":np.random.choice(names,250),
"Gender":np.random.choice(["Male","Female"],250),
"Department":np.random.choice(["IT","HR","Finance","Marketing","Sales"],250),
"Year":np.random.randint(2025,2028,250),
"Maths":np.random.randint(0,100,250),
"science":np.random.randint(0,100,250),
"English":np.random.randint(0,100,250),
"Attendence":np.random.randint(50,100,250),
"Internal mark":np.random.randint(0,25,250)
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      student id             Name  Gender Department  Year  Maths  science  \
# 0            41      Mark Flores  Female         IT  2025     26       57
# 1            26  Anthony Ramirez  Female      Sales  2026      7       78
# 2            27  Amber Davis DVM  Female  Marketing  2026     51       67
# 3            18  Anthony Ramirez  Female      Sales  2026     53       69
# 4            22        Renee Lee    Male  Marketing  2027     80       15
# ..          ...              ...     ...        ...   ...    ...      ...
# 245          33    Brandon Gross  Female  Marketing  2027     30       57
# 246          22    David Charles    Male    Finance  2026     72       31
# 247          30    Donald Wilson  Female  Marketing  2027     85       35
# 248          34      David Lynch  Female         IT  2027     25       18
# 249          41     Billy Curtis    Male         IT  2027     58       73
#
#      English  Attendence  Internal mark
# ...

# %%
df.isnull().sum()
# Out:
# student id       0
# Name             0
# Gender           0
# Department       0
# Year             0
# Maths            0
# science          0
# English          0
# Attendence       0
# Internal mark    0
# dtype: int64

# %%
df["Total"] = df["Maths"] + df["science"] + df["English"]
df["Average"] = df["Total"] / 3

# %%
def grade(avg):
    if avg >= 90:
        return "A"
    elif avg >= 75:
        return "B"
    elif avg >= 50:
        return "C"
    else:
        return "Fail"

# %%
df.describe()
# Out:
#        student id         Year       Maths    science     English  Attendence  \
# count   250.00000   250.000000  250.000000  250.00000  250.000000   250.00000
# mean     39.96000  2025.992000   50.416000   51.95200   47.704000    75.20400
# std      13.34341     0.791481   29.444846   29.54769   28.626812    14.09728
# min      18.00000  2025.000000    0.000000    0.00000    0.000000    50.00000
# 25%      28.25000  2025.000000   24.250000   24.25000   25.000000    63.25000
# 50%      40.00000  2026.000000   52.000000   54.50000   45.500000    76.00000
# 75%      50.00000  2027.000000   77.000000   78.00000   72.750000    86.75000
# max      64.00000  2027.000000   99.000000   99.00000   99.000000    99.00000
#
#        Internal mark       Total     Average
# count     250.000000  250.000000  250.000000
# mean       12.724000  150.072000   50.024000
# std         6.955959   52.342351   17.447450
# min         0.000000   17.000000    5.666667
# ...

# %% [markdown]
# **BAR CHART**

# %%
dept_avg = df.groupby("Department")["Average"].mean()

dept_avg.plot(kind='bar')
plt.title("Department-wise Performance")
plt.xlabel("Department")
plt.ylabel("Average Marks")
plt.show()

# %% [markdown]
# **Pie chart**

# %%
plt.figure()
df["Gender"].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Gender Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# **Histogram**

# %%
plt.figure()
plt.hist(df["Average"], bins=10)
plt.title("Distribution of Average Marks")
plt.xlabel("Average Marks")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **Scatter plot**

# %%
plt.figure()
plt.scatter(df["Attendence"], df["Average"])
plt.title("Attendance vs Average Marks")
plt.xlabel("Attendance")
plt.ylabel("Average Marks")
plt.show()
